# %%
import numpy as np

# ODAS buoy position (decimal degrees)
lat = np.array([43.834516])
lon = np.array([9.118164])

# Deployment date
time = np.array(["2026-01-10"], dtype="datetime64")

# Initial depth in meters
depth = np.array([1000.0])

plan = {
    "lat": lat,
    "lon": lon,
    "time": time,
    "depth": depth,
}

# %%
import sys
print(sys.executable)
# Out:
# /Users/ldelaigue/miniforge3/envs/bcp/bin/python

# %%
from VirtualFleet import FloatConfiguration, Velocity, VirtualFleet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from VirtualFleet import FloatConfiguration, Velocity, VirtualFleet
#
# ModuleNotFoundError: No module named 'VirtualFleet'
